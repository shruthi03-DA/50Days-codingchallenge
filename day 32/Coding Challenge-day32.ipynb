# %%
#1. Even or Odd Checker
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 2
# Even

# %%
#Positive, Negative or Zero
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 6
# Positive

# %%
#Print Numbers from 1 to N (while loop)
n = int(input("Enter N: "))

i = 1
while i <= n:
    print(i)
    i += 1
# Out:
# Enter N: 4
# 1
# 2
# 3
# 4

# %%
#Sum of First N Numbers
n = int(input("Enter N: "))

i = 1
total = 0

while i <= n:
    total += i
    i += 1

print("Sum:", total)
# Out:
# Enter N: 4
# Sum: 10

# %%
#5. Password Retry System
correct_password = "shruthi123"
attempts = 0

while attempts < 3:
    password = input("Enter password: ")

    if password == correct_password:
        print("Access Granted")
        break
    else:
        print("Wrong Password")
        attempts += 1

if attempts == 3:
    print("Access Denied")
# Out:
# Enter password: shruthi123
# Access Granted

# %%
#6. Multiplication Table
num = int(input("Enter a number: "))

i = 1
while i <= 10:
    print(num, "x", i, "=", num * i)
    i += 1
# Out:
# Enter a number: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
